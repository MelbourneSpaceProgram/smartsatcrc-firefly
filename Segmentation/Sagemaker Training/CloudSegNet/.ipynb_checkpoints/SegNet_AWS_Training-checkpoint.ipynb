# %% [markdown]
# # First Attempt at Training Script for SegNet
# * This notebook marks the first attempt to train one of the segmentation models in sagemaker
# * Sagemaker allows you the advantage of being able to send jobs to other instances and training indepenent of the current kernal
# * Previously, training attempted had been interrupted, and progress lost

# %%
############## Set Up ################

import sagemaker
from sagemaker.pytorch import PyTorch
##yan - training on local instance to see what the problem is  
import boto3
import os
from sagemaker.local import LocalSession
from sagemaker.debugger import rule_configs, DebuggerHookConfig, CollectionConfig

sagemaker_session = LocalSession()
sagemaker_session.config = {'local': {'local_code': True}}
# Make sure to set this to your bucket and location
BUCKET_NAME = 'sagemaker-firefly-model-artifacts'
LOCATION_IN_BUCKET = 'smdebug_debug'

s3_bucket_for_tensors = 's3://{BUCKET_NAME}/{LOCATION_IN_BUCKET}'.format(BUCKET_NAME=BUCKET_NAME, LOCATION_IN_BUCKET=LOCATION_IN_BUCKET)
##

# sagemaker_session = sagemaker.Session() #use for remote session

bucket = sagemaker_session.default_bucket()
# prefix = 'sagemaker/DEMO-pytorch-mnist'

role = sagemaker.get_execution_role()

# %%
############# Path Set Up #################
# speciy location of training data
# train_data = 's3://sagemaker-firefly-model-data/Cloud Segmentation Data/38-Cloud_training'.format(bucket, prefix, 'train')
# train_data = 's3://sagemaker-firefly-model-data/Cloud Segmentation Data/38-Cloud_training'
train_data="file:///home/ec2-user/SageMaker/Dataset/CloudSeg/38-Cloud_training"
# validation_data = 's3://{}/{}/{}'.format(bucket, prefix, 'validation') currently training script does this split

# specifiy location for model output to be saved
# s3_output_location = 's3://sagemaker-firefly-model-artifacts'.format(bucket, prefix, 'xgboost_model_sdk')
s3_output_location = 's3://sagemaker-firefly-model-artifacts'

# %%
train_data
# Out:
# 'file:///home/ec2-user/SageMaker/Dataset/CloudSeg/38-Cloud_training'

# %%
############# Initialise the PyTorch training estimator object ###########

#train_instance_type='ml.c4.4xlarge'
estimator = PyTorch(entry_point='Refactored_segnet2_train_script.py',
                    role=role,
                    framework_version='1.4.0',
                    train_instance_count=1,
                    train_instance_type='local',
                    output_path=s3_output_location,
                    hyperparameters={
                        'epochs': 5,
                        'learning_rate':0.001,
                        'batch_size':8
                    },
                    debugger_hook_config = DebuggerHookConfig(
                        s3_output_path=s3_bucket_for_tensors,  # Required
                        collection_configs=[
                            CollectionConfig(
                                name="conv0_tensors",
                                parameters={
                                    "include_regex": "*",
                                    "save_interval": "100"
                                }
                            )
                        ]
                    )
                   )
# estimator = PyTorch(entry_point='segnet2_train_script.py',
#                     role=role,
#                     framework_version='1.4.0',
#                     train_instance_count=1,
#                     train_instance_type='local',
#                     output_path=s3_output_location,
#                     sagemaker_session=sagemaker_session,
#                     hyperparameters={
#                         'epochs': 5,
#                         'learning_rate':0.001,
#                         'backend': 'gloo'
#                     },
#                     debugger_hook_config = DebuggerHookConfig(
#                         s3_output_path=s3_bucket_for_tensors,  # Required
#                         collection_configs=[
#                             CollectionConfig(
#                                 name="conv0_tensors",
#                                 parameters={
#                                     "include_regex": "*",
#                                     "save_interval": "100"
#                                 }
#                             )
#                         ]
#                     )
#                    )

# add train_use_spot_instances = True for spot training

# %%
############## Run the training ################
# estimator.fit({'train': train_data})
estimator.fit({'train': train_data}, wait=False, logs='All') #job runs in background
# Out:
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# Creating tmpt920r_pb_algo-1-y7bzy_1 ...
# Attaching to tmpt920r_pb_algo-1-y7bzy_12mdone
# algo-1-y7bzy_1  | 2020-09-24 00:33:12,565 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# algo-1-y7bzy_1  | 2020-09-24 00:33:12,568 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-y7bzy_1  | 2020-09-24 00:33:12,577 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# algo-1-y7bzy_1  | 2020-09-24 00:33:12,579 sagemaker_pytorch_container.training INFO     Invoking user training script.
# algo-1-y7bzy_1  | 2020-09-24 00:33:13,767 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# algo-1-y7bzy_1  | Generating setup.py
# algo-1-y7bzy_1  | 2020-09-24 00:33:13,767 sagemaker-containers INFO     Generating setup.cfg
# algo-1-y7bzy_1  | 2020-09-24 00:33:13,767 sagemaker-containers INFO     Generating MANIFEST.in
# algo-1-y7bzy_1  | 2020-09-24 00:33:13,768 sagemaker-containers INFO     Installing module with the following command:
# algo-1-y7bzy_1  | /opt/conda/bin/python -m pip install .
# algo-1-y7bzy_1  | Processing /tmp/tmpo9rj55f_/module_dir
# algo-1-y7bzy_1  | Building wheels for collected packages: default-user-module-name
# algo-1-y7bzy_1  |   Building wheel for default-user-module-name (setup.py) ... done
# algo-1-y7bzy_1  |   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=12183 sha256=a1e9b653e4f437eb04488f18b38c445f5b743d55ab4d1dbd4c4bae452cba5fcd
# algo-1-y7bzy_1  |   Stored in directory: /tmp/pip-ephem-wheel-cache-kvydj38e/wheels/2c/c6/89/e988560b301fbe841347912c2d2a6e869126fc5344a4d39b29
# algo-1-y7bzy_1  | Successfully built default-user-module-name
# algo-1-y7bzy_1  | Installing collected packages: default-user-module-name
# algo-1-y7bzy_1  | Successfully installed default-user-module-name-1.0.0
# algo-1-y7bzy_1  | WARNING: You are using pip version 20.1.1; however, version 20.2.3 is available.
# algo-1-y7bzy_1  | You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.
# algo-1-y7bzy_1  | 2020-09-24 00:33:15,312 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-y7bzy_1  | 2020-09-24 00:33:15,324 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-y7bzy_1  | 2020-09-24 00:33:15,335 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-y7bzy_1  | 2020-09-24 00:33:15,343 sagemaker-containers INFO     Invoking user script
# algo-1-y7bzy_1  |
# algo-1-y7bzy_1  | Training Env:
# algo-1-y7bzy_1  |
# algo-1-y7bzy_1  | {
# algo-1-y7bzy_1  |     "additional_framework_parameters": {},
# algo-1-y7bzy_1  |     "channel_input_dirs": {
# algo-1-y7bzy_1  |         "train": "/opt/ml/input/data/train"
# algo-1-y7bzy_1  |     },
# algo-1-y7bzy_1  |     "current_host": "algo-1-y7bzy",
# algo-1-y7bzy_1  |     "framework_module": "sagemaker_pytorch_container.training:main",
# algo-1-y7bzy_1  |     "hosts": [
# algo-1-y7bzy_1  |         "algo-1-y7bzy"
# algo-1-y7bzy_1  |     ],
# algo-1-y7bzy_1  |     "hyperparameters": {
# algo-1-y7bzy_1  |         "epochs": 5,
# algo-1-y7bzy_1  |         "learning_rate": 0.001,
# algo-1-y7bzy_1  |         "batch_size": 8
# algo-1-y7bzy_1  |     },
# algo-1-y7bzy_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-y7bzy_1  |     "input_data_config": {
# algo-1-y7bzy_1  |         "train": {
# algo-1-y7bzy_1  |             "TrainingInputMode": "File"
# algo-1-y7bzy_1  |         }
# algo-1-y7bzy_1  |     },
# algo-1-y7bzy_1  |     "input_dir": "/opt/ml/input",
# algo-1-y7bzy_1  |     "is_master": true,
# algo-1-y7bzy_1  |     "job_name": "pytorch-training-2020-09-24-00-33-08-476",
# algo-1-y7bzy_1  |     "log_level": 20,
# algo-1-y7bzy_1  |     "master_hostname": "algo-1-y7bzy",
# algo-1-y7bzy_1  |     "model_dir": "/opt/ml/model",
# algo-1-y7bzy_1  |     "module_dir": "s3://sagemaker-firefly-model-artifacts/pytorch-training-2020-09-24-00-33-08-476/source/sourcedir.tar.gz",
# algo-1-y7bzy_1  |     "module_name": "Refactored_segnet2_train_script",
# algo-1-y7bzy_1  |     "network_interface_name": "eth0",
# algo-1-y7bzy_1  |     "num_cpus": 8,
# algo-1-y7bzy_1  |     "num_gpus": 0,
# algo-1-y7bzy_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-y7bzy_1  |     "output_dir": "/opt/ml/output",
# algo-1-y7bzy_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-y7bzy_1  |     "resource_config": {
# algo-1-y7bzy_1  |         "current_host": "algo-1-y7bzy",
# algo-1-y7bzy_1  |         "hosts": [
# algo-1-y7bzy_1  |             "algo-1-y7bzy"
# algo-1-y7bzy_1  |         ]
# algo-1-y7bzy_1  |     },
# algo-1-y7bzy_1  |     "user_entry_point": "Refactored_segnet2_train_script.py"
# algo-1-y7bzy_1  | }
# algo-1-y7bzy_1  |
# algo-1-y7bzy_1  | Environment variables:
# algo-1-y7bzy_1  |
# algo-1-y7bzy_1  | SM_HOSTS=["algo-1-y7bzy"]
# algo-1-y7bzy_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-y7bzy_1  | SM_HPS={"batch_size":8,"epochs":5,"learning_rate":0.001}
# algo-1-y7bzy_1  | SM_USER_ENTRY_POINT=Refactored_segnet2_train_script.py
# algo-1-y7bzy_1  | SM_FRAMEWORK_PARAMS={}
# algo-1-y7bzy_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-y7bzy","hosts":["algo-1-y7bzy"]}
# algo-1-y7bzy_1  | SM_INPUT_DATA_CONFIG={"train":{"TrainingInputMode":"File"}}
# algo-1-y7bzy_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-y7bzy_1  | SM_CHANNELS=["train"]
# algo-1-y7bzy_1  | SM_CURRENT_HOST=algo-1-y7bzy
# algo-1-y7bzy_1  | SM_MODULE_NAME=Refactored_segnet2_train_script
# algo-1-y7bzy_1  | SM_LOG_LEVEL=20
# algo-1-y7bzy_1  | SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# algo-1-y7bzy_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-y7bzy_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-y7bzy_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-y7bzy_1  | SM_NUM_CPUS=8
# algo-1-y7bzy_1  | SM_NUM_GPUS=0
# algo-1-y7bzy_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-y7bzy_1  | SM_MODULE_DIR=s3://sagemaker-firefly-model-artifacts/pytorch-training-2020-09-24-00-33-08-476/source/sourcedir.tar.gz
# algo-1-y7bzy_1  | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1-y7bzy","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1-y7bzy"],"hyperparameters":{"batch_size":8,"epochs":5,"learning_rate":0.001},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2020-09-24-00-33-08-476","log_level":20,"master_hostname":"algo-1-y7bzy","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-firefly-model-artifacts/pytorch-training-2020-09-24-00-33-08-476/source/sourcedir.tar.gz","module_name":"Refactored_segnet2_train_script","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-y7bzy","hosts":["algo-1-y7bzy"]},"user_entry_point":"Refactored_segnet2_train_script.py"}
# algo-1-y7bzy_1  | SM_USER_ARGS=["--batch_size","8","--epochs","5","--learning_rate","0.001"]
# algo-1-y7bzy_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-y7bzy_1  | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# algo-1-y7bzy_1  | SM_HP_EPOCHS=5
# algo-1-y7bzy_1  | SM_HP_LEARNING_RATE=0.001
# algo-1-y7bzy_1  | SM_HP_BATCH_SIZE=8
# algo-1-y7bzy_1  | PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# algo-1-y7bzy_1  |
# algo-1-y7bzy_1  | Invoking script with the following command:
# algo-1-y7bzy_1  |
# algo-1-y7bzy_1  | /opt/conda/bin/python Refactored_segnet2_train_script.py --batch_size 8 --epochs 5 --learning_rate 0.001
# algo-1-y7bzy_1  |
# algo-1-y7bzy_1  |
# algo-1-y7bzy_1  | Distributed training - False
# algo-1-y7bzy_1  | Number of gpus available - 0
# algo-1-y7bzy_1  | 10
# algo-1-y7bzy_1  | /opt/ml/model/model.pth
# algo-1-y7bzy_1  | Epoch 0/4
# algo-1-y7bzy_1  | ----------
# Epoch 0/4-1-y7bzy_1  |
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | train Loss: 1.0707 Acc: 1.600000023841858
# algo-1-y7bzy_1  | ----------
# Epoch 0/4-1-y7bzy_1  |
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | valid Loss: 2.6695 Acc: 4.0
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | Epoch 1/4
# algo-1-y7bzy_1  | ----------
# Epoch 1/4-1-y7bzy_1  |
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | train Loss: 1.0697 Acc: 1.600000023841858
# algo-1-y7bzy_1  | ----------
# Epoch 1/4-1-y7bzy_1  |
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | valid Loss: 2.6564 Acc: 4.0
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | Epoch 2/4
# algo-1-y7bzy_1  | ----------
# Epoch 2/4-1-y7bzy_1  |
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | train Loss: 1.0631 Acc: 1.600000023841858
# algo-1-y7bzy_1  | ----------
# Epoch 2/4-1-y7bzy_1  |
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | valid Loss: 2.6434 Acc: 4.0
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | Epoch 3/4
# algo-1-y7bzy_1  | ----------
# Epoch 3/4-1-y7bzy_1  |
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | train Loss: 1.0621 Acc: 1.600000023841858
# algo-1-y7bzy_1  | ----------
# Epoch 3/4-1-y7bzy_1  |
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | valid Loss: 2.6413 Acc: 4.0
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | Epoch 4/4
# algo-1-y7bzy_1  | ----------
# Epoch 4/4-1-y7bzy_1  |
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | train Loss: 1.0621 Acc: 1.600000023841858
# algo-1-y7bzy_1  | ----------
# Epoch 4/4-1-y7bzy_1  |
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | valid Loss: 2.6383 Acc: 4.0
# algo-1-y7bzy_1  | ----------
# algo-1-y7bzy_1  | Training complete in 1m 57s
# algo-1-y7bzy_1  | 2020-09-24 00:35:12,727 sagemaker-containers INFO     Reporting training SUCCESS
# tmpt920r_pb_algo-1-y7bzy_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %%
import numpy as np
import matplotlib.pyplot as plt

def get_data(trial, tname, batch_index, steps_range, mode=modes.GLOBAL):
    tensor = trial.tensor(tname)
    vals = []
    for s in steps_range:
        val = tensor.value(step_num=s, mode=mode)[batch_index][0]
        vals.append(val)
    return vals

def create_plots(steps_range):
    fig, axs = plt.subplots(nrows=1, ncols=len(steps_range), constrained_layout=True, figsize=(2*len(steps_range), 2),
                            subplot_kw={'xticks': [], 'yticks': []})
    return fig, axs

def plot_tensors(trial, layer, batch_index, steps_range):
    if len(steps_range) > 0:    
        fig, axs = create_plots(steps_range)
        vals = get_data(trial, layer, batch_index, steps_range)

        for ax, image, step in zip(axs.flat if isinstance(axs, np.ndarray) else np.array([axs]), vals, steps_range):
            ax.imshow(image, cmap='gray')
            ax.set_title(str(step))
        plt.show()
